# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
performace = pd.read_csv('4 - StudentsPerformance.csv')

# %%
performace
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
nulos = performace.isnull()

# %%
plt.figure( figsize=(16,5 ) )
plt.title('Analise campos nulos')
sns.heatmap(nulos, cbar=False );

# %%
performace.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
performace.duplicated().sum()
# Out:
# 0

# %%
performace.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
performace.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
performace['gender'].value_counts(normalize=True)*100
# Out:
# female    51.8
# male      48.2
# Name: gender, dtype: float64

# %%
performace['race/ethnicity'].value_counts(normalize=True)*100
# Out:
# group C    31.9
# group D    26.2
# group B    19.0
# group E    14.0
# group A     8.9
# Name: race/ethnicity, dtype: float64

# %%
performace['parental level of education'].value_counts(normalize=True)*100
# Out:
# some college          22.6
# associate's degree    22.2
# high school           19.6
# some high school      17.9
# bachelor's degree     11.8
# master's degree        5.9
# Name: parental level of education, dtype: float64

# %%
performace['lunch'].value_counts(normalize=True)*100
# Out:
# standard        64.5
# free/reduced    35.5
# Name: lunch, dtype: float64

# %%
performace['test preparation course'].value_counts(normalize=True)*100
# Out:
# none         64.2
# completed    35.8
# Name: test preparation course, dtype: float64

# %%
sns.boxplot(data=performace, x='math score', y='gender')
# Out:
# <Axes: xlabel='math score', ylabel='gender'>

# %%
sns.boxplot(data=performace, x='reading score', y='gender')
# Out:
# <Axes: xlabel='reading score', ylabel='gender'>

# %%
sns.boxplot(data=performace, x='writing score', y='gender')
# Out:
# <Axes: xlabel='writing score', ylabel='gender'>

# %%
sns.pairplot(performace)

# %%
sns.pairplot(performace, hue='race/ethnicity')
